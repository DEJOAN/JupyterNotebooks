# %% [markdown]
# ![Bandeau-4.jpg](attachment:Bandeau-4.jpg)

# %% [markdown]
# ![Doc1.jpg](attachment:Doc1.jpg)

# %% [markdown]
# ![Doc2.jpg](attachment:Doc2.jpg)

# %% [markdown]
# ![Doc3.jpg](attachment:Doc3.jpg)

# %% [markdown]
# ![Doc4.jpg](attachment:Doc4.jpg)

# %% [markdown]
# ![Consignes.jpg](attachment:Consignes.jpg)

# %% [markdown]
# ![Comp%C3%A9tences.jpg](attachment:Comp%C3%A9tences.jpg)

# %% [markdown]
# # Cellule de réponse de l'étudiant :

# %% [markdown]
# # Notebook pour le tracé de signaux sinusoïdaux
# ### Tracer et additionner deux signaux sinusoïdaux synchrones (de même période)
# Première cellule pour déclarer les bibliothèques à importer :

# %%
#Importation des bibliothèques
import sys
# !{sys.executable} -m pip install numpy
# !{sys.executable} -m pip install matplotlib

import numpy as np
import matplotlib.pyplot as plt
from math import pi

# Affichage avec la bibliothèque graphique intégrée à Notebook
# %matplotlib inline

# %% [markdown]
# Dans un premier temps, vous devez préciser :
# - l'amplitude de chacun des deux signaux (sans unité)
# - leur période, identique (en s)
# - la phase à l'origine de chacun des deux signaux (en rad)

# %%
#Définition de : l'amplitude, la période et du déphasage des 2 signaux
A1 = ...        #Amplitude du signal 1 (sans unité)
A2 = ...        #Amplitude du signal 2 (sans unité)
T = ...         #Période (en s), identique pour les deux signaux "synchrones"
phi1 = ...      #Phase à l'origine du signal 1
phi2 = ...      #Phase à l'origine du signal 2

# %% [markdown]
# Donner l'expression littérale des 3 signaux, *en respectant la notation des paramètres* indiqués dans la cellule précédente :
#
# *Remarque : les valeurs prises par le temps t peuvent être modifiées.*

# %%
#Définition du tableau des dates (en s)
t = np.linspace(0.,20.,2000)

#Définition des courbes
s1 = ...
s2 = ...
s3 = ...

# %% [markdown]
# Les instructions qui suivent assurent et paramètrent le tracé des courbes :
#
# *Précisions :*
#
# *o La fonction cosinus est accessible grâce à la bibliothèque « Numpy » et à l’aide de l’alias « np » utilisé pour
# l’appel de cette bibliothèque, l’instruction est donc la suivante : « np.cos() ».*
#
# *o La constante 𝜋 sera notée « pi » dans le script.*
#
# *o le paramétrage de l'axe des x peut être modifié.*
#
# **Avec Anaconda :** une fois complétées, exécuter l'intégralité des cellules : *Cell $\rightarrow$ Run All*.
#
# **En ligne (my Binder):** une fois complétées, exécuter l'intégralité des cellules : *Run $\rightarrow$ Run all cells*.

# %%
#Tracé des courbes
plt.axis([0,20,-10,10])
plt.xlabel('Temps en s')
plt.ylabel('Amplitude')
plt.title('Somme de deux signaux sinusoïdaux périodiques synchrones')
plt.grid()
c1 = plt.plot(t, s1, '-c', label = r'$s_1$')
c2 = plt.plot(t, s2, '-m', label = r'$s_2$')
c3 = plt.plot(t, s3, '-k', label = r'$s_3$')
plt.legend()

plt.show()
